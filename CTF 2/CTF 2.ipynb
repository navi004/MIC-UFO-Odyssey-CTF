# %%
import numpy as np
import pandas as pd

# %%
file1 = r"C:\Users\nvkaj\Pictures\Learn\MIC\CTF 2\FIFA\FIFA 19 data.csv"
df1 = pd.read_csv(file1)
df1
# Out:
#                     Name  Age          Nationality  Overall  Potential  \
# 0               L. Messi   31            Argentina       94         94
# 1      Cristiano Ronaldo   33             Portugal       94         94
# 2              Neymar Jr   26               Brazil       92         93
# 3                 De Gea   27                Spain       91         93
# 4           K. De Bruyne   27              Belgium       91         92
# ...                  ...  ...                  ...      ...        ...
# 17214         S. Griffin   18  Republic of Ireland       47         67
# 17215        K. Fujikawa   19                Japan       47         61
# 17216           J. Young   18             Scotland       47         62
# 17217       J. Lundstram   19              England       47         65
# 17218          B. Worman   16              England       47         67
#
#                       Club      Value    Wage  Special  \
# 0             FC Barcelona  110500000  565000     2202
# ...

# %% [markdown]
# ## 1. You are currently working as a team manager for a club and are looking to scout for only 80 rated players to hire for your club. Find the total number of 80 rated players available in fifa 19.

# %%
len(df1[df1['Overall'] >= 80])
# Out:
# 554

# %% [markdown]
# ## 2. find the total number of Spanish players in the Fifa 19 game for further analysis and scouting.

# %%
len(df1[df1['Nationality'] == 'Spain'])
# Out:
# 1015

# %% [markdown]
# ## 3.  find the average overall score of players within the value of 10000 and 20000.

# %%
third_df1 = df1[(df1['Value'] >= 10000) & (df1['Value'] <= 20000)]
third_df1
# Out:
#                    Name  Age          Nationality  Overall  Potential  \
# 12396           P. Gori   38                Italy       63         63
# 12639        S. Bywater   37              England       63         63
# 12657        M. McNulty   37  Republic of Ireland       63         63
# 12658          L. Corti   37            Argentina       63         63
# 13502    F. Al Shammari   37         Saudi Arabia       61         61
# 13779      Y. Gutiérrez   37               Mexico       61         61
# 14200          Yang Jun   37             China PR       60         60
# 14545         M. Gurski   39              Germany       60         60
# 14812          M. Tyler   41              England       59         59
# 14884        S. Shearer   37             Scotland       59         59
# 14961       S. Bengriba   37               France       59         59
# 15011           D. Nasu   36                Japan       59         59
# ...

# %%
round(third_df1['Overall'].mean())
# Out:
# 57

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Body Type', 'Position', 'Jersey Number', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause', 'DOB', 'Height', 'Weight', 'Right Foot',
# ...

# %% [markdown]
# ## African Cigarette Prices

# %%
import pandas as pd

file2 = r"C:\Users\nvkaj\Pictures\Learn\MIC\CTF 2\Africa_Cigarette_Prices\cigarrette.csv"

# Try reading with different encodings
try:
    df2 = pd.read_csv(file2, encoding='utf-8')
except UnicodeDecodeError:
    df2 = pd.read_csv(file2, encoding='latin1')

# Display the dataframe
df2
# Out:
# C:\Users\nvkaj\AppData\Local\Temp\ipykernel_17908\152010145.py:9: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(file2, encoding='latin1')
#        Store_ID Round Fieldworker_Code   Country Currency   Day  Month  \
# 0         123.0     1                F   Lesotho      LSL  18.0    1.0
# 1          51.0     1                B   Namibia      NAD  18.0    1.0
# 2          51.0     1                B   Namibia      NAD  18.0    1.0
# 3          52.0     1                B   Namibia      NAD  19.0    1.0
# 4          33.0     1                A    Uganda      UGX  22.0    1.0
# ...         ...   ...              ...       ...      ...   ...    ...
# 215444    416.0    12              251   Lesotho      LSL  20.0    7.0
# 215445    449.0    12              251   Lesotho      LSL  20.0    7.0
# 215446     17.0    12              309  Zimbabwe      ZAR  20.0    7.0
# ...

# %%
df2.columns
# Out:
# Index(['Store_ID', 'Round', 'Fieldworker_Code', 'Country', 'Currency', 'Day',
#        'Month', 'Year', 'Date', 'Province', 'City', 'Suburb', 'Outlet_Type',
#        'Retail_Subtype', 'Outlet_Name', 'Product', 'Brand', 'Sub_Brand',
#        'Quantity', 'Unusual_Quantity_Flg', 'Local_Price',
#        'Local_Price_Per_Stick_Cigarette', 'Dollar_Exchange_Rate',
#        'Dollar_Price', 'Dollar_Price_Per_Stick_Cigarett',
#        'Dollar_Price_Pack_Cigarettes', 'Fieldworker_Comment',
#        'Data_Cleaner_Comment'],
#       dtype='object')

# %% [markdown]
# ### 1.If you were tracking cigarette expenditures in Namibia, how much money, in local currency, would have been spent on cigarettes in total?

# %%
namibia_df = df2[df2['Country'] == 'Namibia']
namibia_df
# Out:
#        Store_ID Round Fieldworker_Code  Country Currency   Day  Month    Year  \
# 1          51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# 2          51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# 3          52.0     1                B  Namibia      NAD  19.0    1.0  2016.0
# 20         51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# 21         51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# ...         ...   ...              ...      ...      ...   ...    ...     ...
# 200140   1378.0    11              307  Namibia      NAD  22.0    1.0  2022.0
# 200158   1366.0    11              281  Namibia      NAD   6.0    1.0  2022.0
# 200167   1207.0    11              307  Namibia      NAD  30.0   12.0  2021.0
# 200172   1327.0    11              281  Namibia      NAD  23.0   12.0  2021.0
# 200181   1205.0    11              307  Namibia      NAD  30.0   12.0  2021.0
#
# ...

# %%
round((namibia_df['Quantity'] * namibia_df['Local_Price_Per_Stick_Cigarette']).sum())
# Out:
# 1475355

# %% [markdown]
# ### 2.Lets say ,you are the finance minister of Lesotho and you have to find the total amount of money spent by your citizens on 18th jan 2016 for a specific reason on cigarettes , what would be your answer?

# %%
ld_df = df2[(df2['Country'] == 'Lesotho') & (df2['Day'] == 18) & (df2['Month'] == 1) & (df2['Year'] == 2016)] 
ld_df
# Out:
#      Store_ID Round Fieldworker_Code  Country Currency   Day  Month    Year  \
# 0       123.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 5        38.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 11      118.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 14       73.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 39       72.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# ...       ...   ...              ...      ...      ...   ...    ...     ...
# 978     122.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 992      70.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 993      73.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 1014    107.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
# 1024    117.0     1                F  Lesotho      LSL  18.0    1.0  2016.0
#
# ...

# %%
(ld_df['Quantity']*ld_df['Local_Price']).sum()
# Out:
# 14644.5

# %% [markdown]
# ### 3.You are a chain smoker in the suburb of Windhoek West and you are on a journey to find the total no of brand of cigarettes you can smoke that can be bought in a retail store?

# %%
brands = df2[(df2['Suburb'] == 'Windhoek West') & (df2['Outlet_Type'] == 'Retail')]['Brand'].unique()
len(brands)
# Out:
# 22

# %% [markdown]
# # Harry Potter

# %%
file3 = r"C:\Users\nvkaj\Pictures\Learn\MIC\CTF 2\Harry_Potter\harry_potter.csv"
df3 = pd.read_csv(file3)
df3
# Out:
#         ID  Intelligence Blood Status  Loyalty Gender  \
# 0        1          30.0  Muggle Born     37.0      F
# 1        2          32.0   Pure Blood     42.0      F
# 2        3          32.0   Pure Blood     38.0      F
# 3        4          28.0  Muggle Born     36.0      F
# 4        5          28.0  Muggle Born     40.0      F
# ...    ...           ...          ...      ...    ...
# 1995  1996          29.0   Pure Blood     35.0      F
# 1996  1997          30.0   Pure Blood     40.0      M
# 1997  1998          33.0   Pure Blood     41.0      M
# 1998  1999          30.0  Muggle Born     40.0      M
# 1999  2000          30.0  Muggle Born     39.0      F
#
#      What are you curious about?  Affinity to Dark Arts  \
# 0             World after we die                  51.94
# 1             World after we die                  54.00
# 2             World after we die                  38.61
# 3              Magical Creatures                  47.50
# ...

# %% [markdown]
# ## Within the Hogwarts Houses Dataset, there are columns for 'House' and 'Kindness.' Find out which magical house boasts the highest average kindness among its members? Share the name of the house and the corresponding rounded off kindness value.

# %%
df3.groupby('House')['Kindness'].mean()
# Out:
# House
# Gryffindor    49.356681
# Hufflepuff    51.563824
# Ravenclaw     50.229742
# Slytherine    48.972794
# Name: Kindness, dtype: float64

# %% [markdown]
# ### 2 Within the enchanted dataset containing information on Hogwarts students, there are columns detailing their magical transportation preferences, particularly the 'Magic Transportation Model' and 'House.' Unveil the Hogwarts house that most frequently employs Portkeys for their magical travels. Share the name of the house and the corresponding count of portkeys used.

# %%
df3[df3['Magic Transportation Model'] == 'Portkey'].groupby('House').count()
# Out:
#              ID  Intelligence  Blood Status  Loyalty  Gender  \
# House
# Gryffindor  178           178           178      178     178
# Hufflepuff  204           204           204      204     204
# Ravenclaw   182           182           182      182     182
# Slytherine  193           193           193      193     193
#
#             What are you curious about?  Affinity to Dark Arts  \
# House
# Gryffindor                          178                    178
# Hufflepuff                          203                    204
# Ravenclaw                           181                    182
# Slytherine                          192                    193
#
#             Magic Transportation Model  Height  Preferred Goblet Potion  \
# House
# Gryffindor                         178     178                      177
# Hufflepuff                         204     204                      201
# Ravenclaw                          182     182                      180
# ...

# %% [markdown]
# ### 3.Deep within the Hogwarts Houses Dataset lies the mystique of magical affiliations, particularly concerning the 'Affinity to Dark Arts.' Find the average affinity to the Dark Arts for Slytherine house. Share the rounded off value of Slytherine’s affinity to dark arts.

# %%
df3_1 = df3[df3['House'] == 'Slytherine']
round(df3_1['Affinity to Dark Arts'].mean())
# Out:
# 49

# %% [markdown]
# ### 4.Embark on a journey into the heart of loyalty within the Hogwarts Houses Dataset. Uncover the house with the least loyalty among its enchanted members. Share the House Name and it’s rounded off value of loyalty.

# %%
df3.groupby('House')['Loyalty'].mean()
# Out:
# House
# Gryffindor    39.668058
# Hufflepuff    39.674952
# Ravenclaw     39.400794
# Slytherine    39.384615
# Name: Loyalty, dtype: float64
